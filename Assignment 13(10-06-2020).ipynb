# %% [markdown]
# # CSE-221710313059-T.Yasasvi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__

# %%
np.__version__

# %%
sns.__version__

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv")
df.head(10)
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0
# 5  345568   r       440.0      1.0     23866   5577.0      4.0
# 6  376865   c       147.0      1.0     10759  17184.0     17.0
# 7  467378   j      2269.0      2.0     54623    312.0      3.0
# 8  393640   j       111.0      2.0    172926  53738.0     79.0
# 9  130054   c      2749.0      1.0     10189    227.0      0.0

# %% [markdown]
# ### Understanding the data
# - How many rows are there in the data?
# - How many columns are there?
# - How many categorical columns are there?
# - Print the categorical column names
# - Print the numerical column names

# %%
print(df.shape[0])
print(df.shape[1])
categorical = df.columns[(df.dtypes.values == np.dtype(object))]
print(categorical)
numerical = df.columns[(df.dtypes.values != np.dtype(object))]
print(numerical)
# Out:
# 330045
# 7
# Index(['Tag'], dtype='object')
# Index(['ID', 'Reputation', 'Answers', 'Username', 'Views', 'Upvotes'], dtype='object')

# %% [markdown]
# ### Observe statistical description of the numerical columns

# %%
df.describe()
# Out:
#                   ID    Reputation        Answers       Username  \
# count  330045.000000  3.300450e+05  330045.000000  330045.000000
# mean   235748.682789  7.773147e+03       3.917672   81442.888803
# std    136039.418471  2.706141e+04       3.579515   49215.100730
# min         1.000000  0.000000e+00       0.000000       0.000000
# 25%    117909.000000  2.820000e+02       2.000000   39808.000000
# 50%    235699.000000  1.236000e+03       3.000000   79010.000000
# 75%    353620.000000  5.118000e+03       5.000000  122559.000000
# max    471493.000000  1.042428e+06      76.000000  175738.000000
#
#               Views        Upvotes
# count  3.300450e+05  330045.000000
# mean   2.964507e+04     337.505358
# std    8.095646e+04    3592.441135
# min    9.000000e+00       0.000000
# 25%    2.594000e+03       8.000000
# 50%    8.954000e+03      28.000000
# 75%    2.687000e+04     107.000000
# max    5.231058e+06  615278.000000

# %% [markdown]
# ### draw a relplot by palcing views on y and upvotes on x
# - draw the plot using data argument
# - draw the plot without using data argument

# %%
sns.relplot("Upvotes","Views",data=df)

# %%
#sns.relplot(df["Upvotes"],df["Views"])

# %% [markdown]
# ### Add another argument for hue the above plot.
# - check it with one numerical column as hue
# - check it with one categorical column as hue

# %%
sns.relplot("Upvotes","Views",data=df,hue="Answers")

# %%
sns.relplot("Upvotes","Views",data=df,hue="Tag")

# %% [markdown]
# ### Modify the above plot using any of the parameters size,style,co

# %%
sns.relplot("Upvotes","Views",data=df,hue="Answers",size=2.5)

# %% [markdown]
# ###  Draw the cat plot by taking tag on xaxis and upvotes on yaxis

# %%
sns.catplot("Tag","Upvotes",data=df)

# %%
sns.catplot("Tag","Answers",data=df)

# %%
plt.plot(df["Answers"],df["Upvotes"])
